# %%
from google.colab import drive
from os.path import join

# %%
ROOT = '/content/drive'     # default for the drive
PROJ = 'My Drive/cloningPushingDriveColab'       # path to your project on Drive

GIT_USERNAME = "suarez-duran-m" # replace with yours
GIT_TOKEN = "7fa7b2f86826d0795fa638db46d89340fddcd4e7"           # definitely replace with yours
GIT_REPOSITORY = "/suarez-duran-m/cloningPushing_fromDriveColab"      # ...nah
GIT_PATH = "https://7fa7b2f86826d0795fa638db46d89340fddcd4e7@github.com/suarez-duran-m/cloningPushing_fromDriveColab.git"
drive.mount(ROOT)           # we mount the drive at /content/drive
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
PROJECT_PATH = join(ROOT, PROJ)
# !mkdir "{PROJECT_PATH}"     # in case we haven't created it already
# Out:
# mkdir: cannot create directory ‘/content/drive/My Drive/cloningPushingDriveColab’: File exists

# %%
PROJECT_PATH = join(ROOT, PROJ)

# !git clone "{GIT_PATH}"
# !rsync -aP cloningPushing_fromDriveColab "{PROJECT_PATH}"
# Out:
# Cloning into 'cloningPushing_fromDriveColab'...
# warning: You appear to have cloned an empty repository.
# sending incremental file list
# cloningPushing_fromDriveColab/
# cloningPushing_fromDriveColab/.git/
# cloningPushing_fromDriveColab/.git/HEAD
#              23 100%    0.00kB/s    0:00:00 (xfr#1, to-chk=23/26)
# cloningPushing_fromDriveColab/.git/config
#             333 100%  325.20kB/s    0:00:00 (xfr#2, to-chk=22/26)
# cloningPushing_fromDriveColab/.git/description
#              73 100%   71.29kB/s    0:00:00 (xfr#3, to-chk=21/26)
# cloningPushing_fromDriveColab/.git/branches/
# cloningPushing_fromDriveColab/.git/hooks/
# cloningPushing_fromDriveColab/.git/hooks/applypatch-msg.sample
#             478 100%  466.80kB/s    0:00:00 (xfr#4, to-chk=15/26)
# cloningPushing_fromDriveColab/.git/hooks/commit-msg.sample
#             896 100%  875.00kB/s    0:00:00 (xfr#5, to-chk=14/26)
# cloningPushing_fromDriveColab/.git/hooks/fsmonitor-watchman.sample
#           3,327 100%    3.17MB/s    0:00:00 (xfr#6, to-chk=13/26)
# cloningPushing_fromDriveColab/.git/hooks/post-update.sample
#             189 100%  184.57kB/s    0:00:00 (xfr#7, to-chk=12/26)
# cloningPushing_fromDriveColab/.git/hooks/pre-applypatch.sample
#             424 100%  414.06kB/s    0:00:00 (xfr#8, to-chk=11/26)
# cloningPushing_fromDriveColab/.git/hooks/pre-commit.sample
#           1,642 100%    1.57MB/s    0:00:00 (xfr#9, to-chk=10/26)
# cloningPushing_fromDriveColab/.git/hooks/pre-push.sample
#           1,348 100%    1.29MB/s    0:00:00 (xfr#10, to-chk=9/26)
# cloningPushing_fromDriveColab/.git/hooks/pre-rebase.sample
#           4,898 100%    4.67MB/s    0:00:00 (xfr#11, to-chk=8/26)
# cloningPushing_fromDriveColab/.git/hooks/pre-receive.sample
#             544 100%  531.25kB/s    0:00:00 (xfr#12, to-chk=7/26)
# cloningPushing_fromDriveColab/.git/hooks/prepare-commit-msg.sample
#           1,492 100%    1.42MB/s    0:00:00 (xfr#13, to-chk=6/26)
# cloningPushing_fromDriveColab/.git/hooks/update.sample
#           3,610 100%    3.44MB/s    0:00:00 (xfr#14, to-chk=5/26)
# cloningPushing_fromDriveColab/.git/info/
# cloningPushing_fromDriveColab/.git/info/exclude
#             240 100%  234.38kB/s    0:00:00 (xfr#15, to-chk=4/26)
# cloningPushing_fromDriveColab/.git/objects/
# cloningPushing_fromDriveColab/.git/objects/info/
# cloningPushing_fromDriveColab/.git/objects/pack/
# cloningPushing_fromDriveColab/.git/refs/
# cloningPushing_fromDriveColab/.git/refs/heads/
# cloningPushing_fromDriveColab/.git/refs/tags/

# %%
#!ls 
#!mv unidad2_partmov drive/My\ Drive/testing_ColbaGithub/
PROJECT_PATH = join(ROOT, PROJ)
# !echo "{PROJECT_PATH}"
# Out:
# /content/drive/My Drive/cloningPushingDriveColab

# %%
# %cd "{PROJECT_PATH}"/unidad2_partmov/
# !ls
# !git config --global user.email "mauricio.suarez@unipamplona.edu.co"
# !git config --global user.name "suarez-duran-m"

# !git remote rm origin

# !git config --global github.user suarez-duran-m
# !git config --global github.token "{GIT_TOKEN}"

# !git add *
# !git commit -m "NoteBook with instruction created."

# !git remote add origin https://"{GIT_TOKEN}"@github.com/"{GIT_REPOSITORY}".git

# !git push -u origin master
# Out:
# /content/drive/My Drive/test_0/unidad2_partmov
# codes
# [master d644109] hi. Added.
#  1 file changed, 1 insertion(+), 1 deletion(-)
# fatal: could not read Password for 'https://58b805a479a066ecae867f9642fad1bb5b8f5481@github.com': No such device or address
