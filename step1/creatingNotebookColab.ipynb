# %% [markdown]
# # How to create a Notebook via Google Colab from https://colab.research.google.com/

# %% [markdown]
# See video:

# %%
from IPython.display import YouTubeVideo
YouTubeVideo('7ju9vYF31ZM')
